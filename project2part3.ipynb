# %% [markdown]
# <a href="https://colab.research.google.com/github/jakew4/project2/blob/main/project2part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NFL Combine Perfomance Data from 2009-2019
# Jacob Wang - 11/02/2022

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
filename = '/content/NFL.csv'
df = pd.read_csv(filename)
df.info()
df.head(8)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3477 entries, 0 to 3476
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 3477 non-null   int64
#  1   Player               3477 non-null   object
#  2   Age                  2927 non-null   float64
#  3   School               3477 non-null   object
#  4   Height               3477 non-null   float64
#  5   Weight               3477 non-null   float64
#  6   Sprint_40yd          3303 non-null   float64
#  7   Vertical_Jump        2780 non-null   float64
#  8   Bench_Press_Reps     2572 non-null   float64
#  9   Broad_Jump           2749 non-null   float64
#  10  Agility_3cone        2260 non-null   float64
#  11  Shuttle              2337 non-null   float64
#  12  Drafted..tm.rnd.yr.  2254 non-null   object
#  13  BMI                  3477 non-null   float64
#  14  Player_Type          3477 non-null   object
#  15  Position_Type        3477 non-null   object
#  16  Position             3477 non-null   object
#  17  Drafted              3477 non-null   object
# dtypes: float64(10), int64(1), object(7)
# memory usage: 489.1+ KB
#    Year                     Player   Age          School  Height      Weight  \
# 0  2009      Beanie Wells\WellCh00  20.0        Ohio St.  1.8542  106.594207
# 1  2009        Will Davis\DaviWi99  22.0        Illinois  1.8796  118.387609
# 2  2009    Herman Johnson\JohnHe23  24.0             LSU  2.0066  165.107623
# 3  2009    Rashad Johnson\JohnRa98  23.0         Alabama  1.8034   92.079251
# 4  2009        Cody Brown\BrowCo96  22.0     Connecticut  1.8796  110.676538
# 5  2009   Trevor Canfield\CanfTr20  23.0      Cincinnati  1.9304  139.252858
# 6  2009       Peria Jerry\JerrPe99  24.0     Mississippi  1.8796  135.624119
# 7  2009  Garrett Reynolds\ReynGa20  21.0  North Carolina  2.0320  140.160042
#
#    Sprint_40yd  Vertical_Jump  Bench_Press_Reps  Broad_Jump  Agility_3cone  \
# 0         4.38          85.09              25.0      325.12            NaN
# 1         4.84          83.82              27.0      292.10           7.38
# 2         5.50            NaN              21.0         NaN            NaN
# 3         4.49          93.98              15.0      304.80           7.09
# 4         4.76          92.71              26.0      304.80           7.10
# 5         5.28            NaN              29.0         NaN            NaN
# 6         4.98            NaN               NaN         NaN            NaN
# 7         5.32          55.88              19.0      238.76           7.87
#
#    Shuttle                          Drafted..tm.rnd.yr.        BMI  \
# 0      NaN   Arizona Cardinals / 1st / 31st pick / 2009  31.004194
# 1     4.45  Arizona Cardinals / 6th / 204th pick / 2009  33.510073
# 2      NaN  Arizona Cardinals / 5th / 167th pick / 2009  41.005821
# 3     4.23   Arizona Cardinals / 3rd / 95th pick / 2009  28.312463
# 4     4.40   Arizona Cardinals / 2nd / 63rd pick / 2009  31.327425
# 5      NaN  Arizona Cardinals / 7th / 254th pick / 2009  37.368830
# 6      NaN     Atlanta Falcons / 1st / 24th pick / 2009  38.388934
# 7     4.88    Atlanta Falcons / 5th / 156th pick / 2009  33.945078
#
#   Player_Type      Position_Type Position Drafted
# 0     offense    backs_receivers       RB     Yes
# 1     defense  defensive_lineman       DE     Yes
# 2     offense  offensive_lineman       OG     Yes
# 3     defense     defensive_back       FS     Yes
# 4     defense        line_backer      OLB     Yes
# 5     offense  offensive_lineman       OG     Yes
# 6     defense  defensive_lineman       DT     Yes
# 7     offense  offensive_lineman       OT     Yes

# %% [markdown]
# # Data Cleaning

# %%
# create copy of original df
ml_df = df.copy()

# %%
# Delete unnecessary columns 
ml_df = ml_df.drop(columns = ['Year', 'Player', 'Drafted..tm.rnd.yr.'])

# %% [markdown]
# We can drop year and player name because these will likely not affect our analysis. The 'Drafted..tm.rnd.yr' column can also be dropped, because this column essentially tell us whether or not the player was drafted. The 'Drafted' column also contains this information so unless we want to find what round each player was picked, we can drop this column.

# %%
# Determine if there are duplicate rows
ml_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# NO duplicates

# %%
# Identify missing values:
ml_df.isna().sum()
# Out:
# Age                  550
# School                 0
# Height                 0
# Weight                 0
# Sprint_40yd          174
# Vertical_Jump        697
# Bench_Press_Reps     905
# Broad_Jump           728
# Agility_3cone       1217
# Shuttle             1140
# BMI                    0
# Player_Type            0
# Position_Type          0
# Position               0
# Drafted                0
# dtype: int64

# %% [markdown]
# Address missing values: There are an excess of missing numerical values in various columns because some position types will only participate in certain combine exercises. For example, an offensive lineman would be more likely to participate in exercises that showcase strength such as the bench press. Similarly, a running back or wide receiver would be more likely to participate in events that showcase speed and agility such as the agility 3-cone event or 40 yard dash. To fill in these missing values, I will simply insert the average of the column using SimpleImputer. This shouldn't affect analysis too heavily, as the most important data from each player most likely won't be missing. Will NOT fill in missing values here since this will result in data leakage when we begin modeling. I will fill missing values with preprocessing pipeline when the time comes.

# %%
# Identify and address categorical inconsistencies
ml_df['Drafted'].value_counts()
ml_df['School'].value_counts()
ml_df['Position'].value_counts()
ml_df['Position_Type'].value_counts()
ml_df['Player_Type'].value_counts()
# Out:
# offense          1815
# defense          1538
# special_teams     124
# Name: Player_Type, dtype: int64

# %% [markdown]
# All categorical columns are in order.

# %%
# identify numerical outliers 
ml_df.describe()
# Out:
#                Age       Height       Weight  Sprint_40yd  Vertical_Jump  \
# count  2927.000000  3477.000000  3477.000000  3303.000000    2780.000000
# mean     21.983259     1.873968   109.746393     4.769080      83.392403
# std       0.969490     0.067494    20.483780     0.301477      10.678403
# min      18.000000     1.651000    67.585263     4.220000      44.450000
# 25%      21.000000     1.828800    92.986436     4.530000      76.200000
# 50%      22.000000     1.879600   104.779837     4.690000      83.820000
# 75%      23.000000     1.930400   125.645087     4.960000      90.170000
# max      28.000000     2.082800   167.375585     6.000000     114.300000
#
#        Bench_Press_Reps   Broad_Jump  Agility_3cone      Shuttle          BMI
# count       2572.000000  2749.000000    2260.000000  2337.000000  3477.000000
# mean          20.241058   291.629698       7.237416     4.403843    31.074417
# std            6.497600    23.960879       0.410230     0.265224     4.438279
# min            2.000000   198.120000       6.280000     3.810000    21.609798
# 25%           15.000000   276.860000       6.940000     4.200000    27.475641
# 50%           20.000000   294.640000       7.140000     4.360000    30.122626
# 75%           25.000000   307.340000       7.490000     4.560000    34.038647
# max           49.000000   373.380000       9.040000     5.560000    44.680097

# %% [markdown]
# There does not seem to be any significant outliers in the numerical data.

# %% [markdown]
# # Exploratory Visuals

# %%
# Create boxplots to view statistical summaries of 40yd dash times
# and whether or not player was drafted
sns.boxplot(x = 'Drafted', y = 'Sprint_40yd', data = ml_df)
plt.xticks(rotation = 45);

# %% [markdown]
# As can be expected, those with a faster 40-yard dash time are slightly more likely to be drafted. The amount of slower times is higher amongst undrafted players.

# %%
# Create boxplots to view statistical summaries of Age
# and whether or not player was drafted
sns.boxplot(x = 'Drafted', y = 'Age', data = ml_df)
plt.xticks(rotation = 45);

# %%
# create boxplot of bench press reps and drafted (Yes/No)
sns.boxplot(x = 'Drafted', y = 'Bench_Press_Reps', data = ml_df)
plt.xticks(rotation = 45);

# %%
# create boxplot of vertical jump stats and drafted (Yes/No)
sns.boxplot(x = 'Drafted', y = 'Vertical_Jump', data = ml_df)
plt.xticks(rotation = 45);

# %%
# create boxplot of broad jump stats and drafted (Yes/No)
sns.boxplot(x = 'Drafted', y = 'Broad_Jump', data = ml_df)
plt.xticks(rotation = 45);

# %%
# create boxplot of agility cone drill stats and drafted (Yes/No)
sns.boxplot(x = 'Drafted', y = 'Agility_3cone', data = ml_df)
plt.xticks(rotation = 45);

# %%
# create boxplot of shuttle run stats and drafted (Yes/No)
sns.boxplot(x = 'Drafted', y = 'Shuttle', data = ml_df)
plt.xticks(rotation = 45);

# %%
# display scatterplot of BMI vs. 40-Yard Dash time by Drafted (Y/N)
ax = sns.scatterplot(data = ml_df, x = 'BMI', y = 'Sprint_40yd', hue = 'Drafted', palette = 'plasma')
ax.set_title('BMI vs. 40-yd Dash Time by Drafted (Y/N)')
ax.set_xlabel('BMI')
ax.legend(bbox_to_anchor = [1,1]);

# %%
# Create barplot of 'Vertical_jump' and 'Drafted';
sns.barplot(data = df, x = 'Vertical_Jump', y ='Drafted');
plt.xticks(rotation=45);

# %%
# Create histogram of 'Drafted' column
sns.histplot(data = ml_df, x = 'Drafted');
plt.title('Distribution of Drafted/Undrafted Players')
plt.ylabel('Number of players');
plt.xlabel('Drafted?');

# %% [markdown]
# # Explanatory Visuals

# %%
# Display a correlation heatmap of features
corr = ml_df.corr()
plt.figure(figsize = (10,5))
sns.heatmap(corr, cmap = 'Greens', annot = True);

# %% [markdown]
# There are lots of strong correlations between our features. As can be expected, weight and BMI have strong correlation with each other, as well as most of the different combine drills. As weight increases, 40-yard dash and shuttle times tended to increase as well. Bench press reps also has a strong positive correlation with weight/BMI. The two jumping events (broad and vertical jump) had strong negative correlations with weight and BMI. This is natural as lighter players would tend to be able to jump higher. The broad and vertical jump also have strong negative correlations with the running events (40 yd dash and shuttle).

# %%
# Create boxplots to view statistical summaries of 40yd dash times
# by position type
sns.boxplot(y = 'Position_Type', x = 'Sprint_40yd', data = ml_df)
plt.xticks(rotation = 45);
plt.title('40-yard Dash Times by Position Type')
plt.tight_layout()

# %% [markdown]
# As expected, skill position types such as backs/receivers and defensive backs are on average, quicker than the rest of position types. Offensive and defensive linemen have the slowest times, as they typically weigh much more than other position types.

# %%
# display scatterplot of BMI vs. Bench_Press_Reps by Drafted (Y/N)
ax = sns.scatterplot(data = ml_df, x = 'BMI', y = 'Bench_Press_Reps', hue = 'Drafted', palette = 'cubehelix')
ax.set_title('BMI vs. Bench_Press_Reps by Drafted (Y/N)')
ax.set_xlabel('BMI')
ax.legend(bbox_to_anchor = [1,1]);

# %% [markdown]
# As can be expected, as BMI/weight increased, so did bench press reps. The scatterplot shows that there was a significant positive relationship between BMI and bench press reps. Players who were drafted had slightly higher rep numbers. However, many players with similar numbers were also not drafted. Most of the players with lower reps are concentrated towards the lower side of BMI and were also not drafted.
